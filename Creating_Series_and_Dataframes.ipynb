# %% [markdown]
# # Pokemon

# %% [markdown]
# ### Introduction:
#
# This time you will create the data.
#
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Create a data dictionary that looks like the DataFrame below

# %%
pokemon = pd.DataFrame({
                   'evalution': ['Ivysaur', 'Charmeleon', 'Wartortle', 'Metapod'],
                   'hp': [45, 39, 44, 45],
                   'name': ['Bulbasaur', 'Charmander', 'Squirtle', 'Caterpie'],
                   'pokedex': ['yes', 'no','yes','no'],
                   'type': ['grass', 'fire', 'water', 'bug']
                  })

# %% [markdown]
# ### Step 3. Assign it to a variable called pokemon

# %%
pokemon
# Out:
#     evalution  hp        name pokedex   type
# 0     Ivysaur  45   Bulbasaur     yes  grass
# 1  Charmeleon  39  Charmander      no   fire
# 2   Wartortle  44    Squirtle     yes  water
# 3     Metapod  45    Caterpie      no    bug

# %% [markdown]
# ### Step 4. Ops...it seems the DataFrame columns are in alphabetical order. Place  the order of the columns as name, type, hp, evolution, pokedex

# %%
new_columns = ['name', 'type', 'hp','evolution', 'pokedex']
pokemon = pokemon.reindex(columns = new_columns)
pokemon
# Out:
#          name   type  hp  evolution pokedex
# 0   Bulbasaur  grass  45        NaN     yes
# 1  Charmander   fire  39        NaN      no
# 2    Squirtle  water  44        NaN     yes
# 3    Caterpie    bug  45        NaN      no

# %% [markdown]
# ### Step 5. Add another column called place, and insert what you have in mind.

# %%
pokemon['place'] = ['İstanbul', 'İzmir', 'Ankara', 'Samsun']
pokemon
# Out:
#          name   type  hp  evolution pokedex     place
# 0   Bulbasaur  grass  45        NaN     yes  İstanbul
# 1  Charmander   fire  39        NaN      no     İzmir
# 2    Squirtle  water  44        NaN     yes    Ankara
# 3    Caterpie    bug  45        NaN      no    Samsun

# %% [markdown]
# ### Step 6. Present the type of each column

# %%
pokemon.dtypes
# Out:
# name          object
# type          object
# hp             int64
# evolution    float64
# pokedex       object
# place         object
# dtype: object
